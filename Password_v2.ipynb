# %% [markdown]
# <a href="https://colab.research.google.com/github/nehalrakesh/Python_practice/blob/main/Password_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
userlist = ["120031","120032","120033","120034","120035"]
password = ["dsfh@dhfF1","2k$fhgdur","55gi%hdj","kd__6kfg","ksd#j898fk"]
pass_dict ={}

n= len(userlist)

for i in range(0,n):
  pass_dict[userlist[i]] = password[i]

print(pass_dict)
# Out:
# {'120031': 'dsfh@dhfF1', '120032': '2k$fhgdur', '120033': '55gi%hdj', '120034': 'kd__6kfg', '120035': 'ksd#j898fk'}

# %%
userid = input("Please enter your user ID:    ")
if userid not in userlist:
  print("you are not an existing user\n Do you want to create new userID?(YES/NO)")
  response = input("YES/NO:    ")
  if response.upper() == "YES":
    print("Please set up password to become a registered user")
    pass1 = input("Please enter your password:    ")
    pformat =[]
    
    if len(pass1) <8:
      print("Password should be minimum 8 characters ")
      pass1a = input("Please enter your password(Attemp2):    ")
      if len(pass1a) <8:
        print("Password should be minimum 8 characters,Please try again. Maximum attempt reached ")
      else:
        numer =0
        ucase = 0
        lcase =0
        spchar =0


        for i in pass1a:
          asc = ord(i)
          if asc in range(33,48) or asc in range(58,65) or asc in range(95,97):
            spchar+=1
          elif asc in range(48,58) :
            numer+=1
          elif asc in range(65,91) :
            ucase +=1
          elif asc in range(97,123):
            lcase +=1

        pformat1=[numer,ucase,lcase,spchar]
        # print(pformat)

        if 0 in pformat1:
          print("Password should have atleast a numeric, an uppercase, a smallcase and a special character")
        elif pformat1 !=pformat:
          pass2 = input("Please confirm your password:    ")
          if pass2 != pass1a:
            print("Your passwords do not match")
            pass3 = input("Please confirm your password(attempt2):    ")
            if pass3 != pass1a:
              print("Your passwords do not match, Please refresh")
            else:
              userlist.append(userid)
              pass_dict[userid] = pass1a
              print("Your userID is",userid,"and Your password is saved")
          else:
            userlist.append(userid)
            pass_dict[userid] = pass1a
            print("Your userID is",userid,"and Your password is saved")


    else:
      numer =0
      ucase = 0
      lcase =0
      spchar =0


      for i in pass1:
        asc = ord(i)
        if asc in range(33,48) or asc in range(58,65) or asc in range(95,97):
          spchar+=1
        elif asc in range(48,58) :
          numer+=1
        elif asc in range(65,91) :
          ucase +=1
        elif asc in range(97,123):
          lcase +=1
        
      pformat1=[numer,ucase,lcase,spchar]
    # print(pformat)

      if 0 in pformat1:
        print("Password should have atleast a numeric, an uppercase, a smallcase and a special character")
      elif pformat1 !=pformat:
        pass2 = input("Please confirm your password:    ")
        if pass2 != pass1:
          print("Your passwords do not match")
          pass3 = input("Please confirm your password(attempt2):    ")
          if pass3 != pass1:
            print("Your passwords do not match, Please refresh")
          else:
            userlist.append(userid)
            pass_dict[userid] = pass1
            print("Your userID is",userid,"and Your password is saved")
        else:
          userlist.append(userid)
          pass_dict[userid] = pass1
          print("Your userID is",userid,"and Your password is saved")

  elif response.upper() == "NO":
      print("Thank you for visiting")
  else:
      print("You have entered entered incorrect response. Please refresh")

elif userid in userlist:
  print("You are a registered user")
  pass_old= input("Please enter your old password:    ")
  if pass_old != pass_dict[userid]:
    print("You have entered incorrect password. Please try again")

  else:
    pass1 = input("Please enter your new password:    ")
    pformat =[]
    
    if len(pass1) <8:
      print("Password should be minimum 8 characters ")
      pass1a = input("Please enter your password(Attemp2):    ")
      if len(pass1a) <8:
        print("Password should be minimum 8 characters,Please try again. Maximum attempt reached ")
      else:
        numer =0
        ucase = 0
        lcase =0
        spchar =0


        for i in pass1a:
          asc = ord(i)
          if asc in range(33,48) or asc in range(58,65) or asc in range(95,97):
            spchar+=1
          elif asc in range(48,58) :
            numer+=1
          elif asc in range(65,91) :
            ucase +=1
          elif asc in range(97,123):
            lcase +=1
          
        pformat1=[numer,ucase,lcase,spchar]
        # print(pformat1)

        if 0 in pformat1:
            print("Password should have atleast a numeric, an uppercase, a smallcase and a special character")
            
        elif pformat1 != pformat:
          pass2 = input("Please confirm your password:    ")
          if pass2 != pass1a:
            print("Your passwords do not match")
            pass3 = input("Please confirm your password(attempt2):    ")
            if pass3 != pass1a:
              print("Your passwords do not match, Please refresh")
            else:
              userlist.append(userid)
              pass_dict[userid] = pass1a
              print("Your userID is",userid,"and Your password is saved")
          else:
            userlist.append(userid)
            pass_dict[userid] = pass1a
            print("Your userID is",userid,"and Your password is saved")

    else:
      numer =0
      ucase = 0
      lcase =0
      spchar =0


      for i in pass1:
        asc = ord(i)
        if asc in range(33,48) or asc in range(58,65) or asc in range(95,97):
          spchar+=1
        elif asc in range(48,58) :
          numer+=1
        elif asc in range(65,91) :
          ucase +=1
        elif asc in range(97,123):
          lcase +=1
        
      pformat1=[numer,ucase,lcase,spchar]
      # print(pformat1)

      if 0 in pformat1:
          print("Password should have atleast a numeric, an uppercase, a smallcase and a special character")
          
      elif pformat1 != pformat:
        pass2 = input("Please confirm your password:    ")
        if pass2 != pass1:
          print("Your passwords do not match")
          pass3 = input("Please confirm your password(attempt2):    ")
          if pass3 != pass1:
            print("Your passwords do not match, Please refresh")
          else:
            userlist.append(userid)
            pass_dict[userid] = pass1
            print("Your userID is",userid,"and Your password is saved")
        else:
          userlist.append(userid)
          pass_dict[userid] = pass1
          print("Your userID is",userid,"and Your password is saved")

pass_dict
# Out:
# Please enter your user ID:    nehalrakesh01
# You are a registered user
# Please enter your old password:    Nehalbhaiya@04
# Please enter your new password:    Nehalbhaiya@26
# [2, 1, 10, 1]
# Please confirm your password:    Nehalbhaiya@26
# Your userID is nehalrakesh01 and Your password is saved
# {'120031': 'dsfh@dhfF1',
#  '120032': '2k$fhgdur',
#  '120033': '55gi%hdj',
#  '120034': 'kd__6kfg',
#  '120035': 'ksd#j898fk',
#  'nehalrakesh01': 'Nehalbhaiya@26'}
